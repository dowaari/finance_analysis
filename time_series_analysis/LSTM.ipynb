# %%
import pandas as pd
import pandas_datareader.data as reader
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation
from keras.callbacks import EarlyStopping
from pandas.plotting import register_matplotlib_converters
from pykrx import stock
register_matplotlib_converters()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 주식 데이터 Data 가져오기
# `Pykrx` 를 사용해 삼성전자 `005930.KS` 의 5년치 주가 정보 로딩

# %%
data = stock.get_market_ohlcv_by_date("20150518", "20200518", "005930")
print(data.info())

data.head()

# data = reader.DataReader('005930.KS', 'yahoo', '2015.02.01', '2020.1.31')
# print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1228 entries, 2015-05-18 to 2020-05-18
# Data columns (total 5 columns):
# 시가     1228 non-null int32
# 고가     1228 non-null int32
# 저가     1228 non-null int32
# 종가     1228 non-null int32
# 거래량    1228 non-null int32
# dtypes: int32(5)
# memory usage: 33.6 KB
# None
#                시가     고가     저가     종가     거래량
# 날짜
# 2015-05-18  26700  26700  26180  26400  192537
# 2015-05-19  26419  27100  26139  26760  173618
# 2015-05-20  26980  27400  26820  27320  205829
# 2015-05-21  27420  27440  26880  27040  144212
# 2015-05-22  27060  27060  26700  27000  163916

# %%
# %matplotlib inline
plt.plot(data.index, data['종가'], label='close')
plt.legend()

# %% [markdown]
# ### Data Normalization
# 학습 효율을 높이기 위해 데이터를 0 ~ 1 사이의 값으로 정규화
#
#
# `MinMaxScaler` 를 사용한다. 이때 `train_data` 와 `test_data` 는 같은 `scaler` 를 사용해 정규화해야 한다.

# %%
data_set = data[['종가']].values
scaler = MinMaxScaler()
nomalized_data_set = scaler.fit_transform(data_set)
nomalized_data_set
# Out:
# array([[0.12323429],
#        [0.13200195],
#        [0.14564053],
#        ...,
#        [0.64929372],
#        [0.64564053],
#        [0.6687774 ]])

# %% [markdown]
# ### Window 생성
# LSTM 학습을 위해 window 생성, `window_len=5` 이면 5일치 데이터를 바탕으로 다음날 데이터를 예측

# %%
window_len = 5
sequence_length = window_len + 1
result = []
date_idx = []

for index in range(len(nomalized_data_set) - sequence_length):
    result.append(nomalized_data_set[index: index + sequence_length])
    date_idx.append(data.index[index + sequence_length-1])
    
# result = [data_set[i:i+sequence_length] for i in range(len(date_set) - sequence_length)]
result = np.array(result)

# %%
print(result[0])
# Out:
# [[0.12323429]
#  [0.13200195]
#  [0.14564053]
#  [0.13882124]
#  [0.13784705]
#  [0.14369216]]

# %%
train_ratio = 0.75
train_num = int(round(result.shape[0] * train_ratio))
train = result[:train_num, :]
np.random.seed(10)
np.random.shuffle(train)

x_train = train[:, :-1]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = result[:train_num, -1]

x_test = result[train_num:, :-1]
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[train_num:, -1]

x_train.shape, x_test.shape
# Out:
# ((916, 5, 1), (306, 5, 1))

# %%
plt.plot([0, 1, 2, 4, 5], x_train[0].flatten(), 'bo-', label="X_train")
plt.plot([6], y_train[0], 'ro', label="Y_train")
plt.legend()
plt.title("First sample")
# Out:
# Text(0.5, 1.0, 'First sample')

# %% [markdown]
# ### LSTM 모델 생성
# `Sequential()` 모델을 사용해 LSTM layer 2개와 Dense layer 1개를 연결
#
# 회귀 문제이기 때문에 출력층 activation function은 `linear` (선형),  loss function은 `mean squred error` (평균 제곱 오류) 를 사용
#
# 최적화 함수는 일반적으로 가장 많이 사용되는 `adam`을 사용

# %%
model = Sequential()
model.add(LSTM(32, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(1, activation='linear'))
model.compile(loss='mse', optimizer='adam')

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 5, 32)             4352
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 64)                24832
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 29,249
# Trainable params: 29,249
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습
# 한 번에 `batch_size` 만큼 학습시키며 `epochs` 만큼 반복학습
#
# `EarlyStopping` callback을 사용해 `val_loss` 의 개선이 없을 경우 학습 조기 종료

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
training_result = model.fit(x_train, y_train, validation_data=(x_test, y_test), 
                            batch_size=10, epochs=150, callbacks=[early_stop])
# Out:
# Train on 916 samples, validate on 306 samples
# Epoch 1/150
# 916/916 [==============================] - 5s 6ms/step - loss: 0.0272 - val_loss: 0.0020
# Epoch 2/150
# 916/916 [==============================] - 2s 2ms/step - loss: 9.0626e-04 - val_loss: 0.0018
# Epoch 3/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.8080e-04 - val_loss: 0.0015
# Epoch 4/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.6015e-04 - val_loss: 0.0015
# Epoch 5/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.2771e-04 - val_loss: 0.0014
# Epoch 6/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.4064e-04 - val_loss: 0.0015
# Epoch 7/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.4254e-04 - val_loss: 0.0014
# Epoch 8/150
# 916/916 [==============================] - 1s 2ms/step - loss: 7.4277e-04 - val_loss: 0.0015
# Epoch 9/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.6984e-04 - val_loss: 0.0014
# Epoch 10/150
# 916/916 [==============================] - 1s 2ms/step - loss: 6.7981e-04 - val_loss: 0.0016
# Epoch 11/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.6377e-04 - val_loss: 0.0014
# Epoch 12/150
# 916/916 [==============================] - 2s 2ms/step - loss: 6.8083e-04 - val_loss: 0.0014
# Epoch 13/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.3011e-04 - val_loss: 0.0015
# Epoch 14/150
# 916/916 [==============================] - 2s 2ms/step - loss: 9.2726e-04 - val_loss: 0.0013
# Epoch 15/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.2030e-04 - val_loss: 0.0015
# Epoch 16/150
# 916/916 [==============================] - 2s 2ms/step - loss: 6.9531e-04 - val_loss: 0.0013
# Epoch 17/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.0898e-04 - val_loss: 0.0013
# Epoch 18/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.0113e-04 - val_loss: 0.0017
# Epoch 19/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.3369e-04 - val_loss: 0.0023
# Epoch 20/150
# 916/916 [==============================] - 2s 2ms/step - loss: 7.3512e-04 - val_loss: 0.0012
# Epoch 21/150
# 916/916 [==============================] - 2s 2ms/step - loss: 6.5730e-04 - val_loss: 0.0012
# Epoch 22/150
# 916/916 [==============================] - 2s 2ms/step - loss: 6.1839e-04 - val_loss: 0.0013
# Epoch 23/150
# 916/916 [==============================] - 2s 2ms/step - loss: 6.7348e-04 - val_loss: 0.0012
# Epoch 24/150
# 916/916 [==============================] - 2s 2ms/step - loss: 6.4306e-04 - val_loss: 0.0012
# Epoch 25/150
# 916/916 [==============================] - 1s 2ms/step - loss: 5.8544e-04 - val_loss: 0.0014
# Epoch 26/150
# 916/916 [==============================] - 2s 2ms/step - loss: 6.3424e-04 - val_loss: 0.0012
# Epoch 27/150
# 916/916 [==============================] - 2s 2ms/step - loss: 6.6791e-04 - val_loss: 0.0012
# Epoch 28/150
# 916/916 [==============================] - 2s 2ms/step - loss: 6.1727e-04 - val_loss: 0.0011
# Epoch 29/150
# 916/916 [==============================] - 2s 2ms/step - loss: 5.6735e-04 - val_loss: 0.0010
# Epoch 30/150
# 916/916 [==============================] - 2s 2ms/step - loss: 5.9364e-04 - val_loss: 0.0011
# Epoch 31/150
# 916/916 [==============================] - 2s 2ms/step - loss: 5.4407e-04 - val_loss: 0.0011
# Epoch 32/150
# 916/916 [==============================] - 2s 2ms/step - loss: 5.3290e-04 - val_loss: 9.4655e-04
# Epoch 33/150
# 916/916 [==============================] - 2s 2ms/step - loss: 5.5623e-04 - val_loss: 0.0010
# Epoch 34/150
# 916/916 [==============================] - 2s 2ms/step - loss: 5.2928e-04 - val_loss: 9.5475e-04
# Epoch 35/150
# 916/916 [==============================] - 2s 2ms/step - loss: 5.5390e-04 - val_loss: 9.8333e-04
# Epoch 36/150
# 916/916 [==============================] - 2s 2ms/step - loss: 4.9373e-04 - val_loss: 8.3473e-04
# Epoch 37/150
# 916/916 [==============================] - 2s 2ms/step - loss: 4.9439e-04 - val_loss: 8.1181e-04
# Epoch 38/150
# 916/916 [==============================] - 2s 2ms/step - loss: 5.5212e-04 - val_loss: 7.9258e-04
# Epoch 39/150
# 916/916 [==============================] - 1s 2ms/step - loss: 4.4849e-04 - val_loss: 7.9972e-04
# Epoch 40/150
# 916/916 [==============================] - 1s 2ms/step - loss: 4.6991e-04 - val_loss: 9.1044e-04
# Epoch 41/150
# 916/916 [==============================] - 1s 2ms/step - loss: 4.3967e-04 - val_loss: 7.0195e-04
# Epoch 42/150
# 916/916 [==============================] - 1s 2ms/step - loss: 4.4409e-04 - val_loss: 0.0012
# Epoch 43/150
# 916/916 [==============================] - 2s 2ms/step - loss: 4.3879e-04 - val_loss: 6.7511e-04
# Epoch 44/150
# 916/916 [==============================] - 2s 2ms/step - loss: 4.0235e-04 - val_loss: 8.0329e-04
# Epoch 45/150
# 916/916 [==============================] - 1s 2ms/step - loss: 3.7972e-04 - val_loss: 5.7799e-04
# Epoch 46/150
# 916/916 [==============================] - 2s 2ms/step - loss: 4.1702e-04 - val_loss: 0.0013
# Epoch 47/150
# 916/916 [==============================] - 2s 2ms/step - loss: 4.2885e-04 - val_loss: 7.7291e-04
# Epoch 48/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.8947e-04 - val_loss: 6.2331e-04
# Epoch 49/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.6444e-04 - val_loss: 8.0892e-04
# Epoch 50/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.5158e-04 - val_loss: 5.0747e-04
# Epoch 51/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.6243e-04 - val_loss: 5.1743e-04
# Epoch 52/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.2202e-04 - val_loss: 7.8120e-04
# Epoch 53/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.7965e-04 - val_loss: 4.8607e-04
# Epoch 54/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.3699e-04 - val_loss: 4.7886e-04
# Epoch 55/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.2650e-04 - val_loss: 4.7361e-04
# Epoch 56/150
# 916/916 [==============================] - 2s 2ms/step - loss: 2.9906e-04 - val_loss: 6.7498e-04
# Epoch 57/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.7260e-04 - val_loss: 6.3477e-04
# Epoch 58/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.1803e-04 - val_loss: 4.5754e-04
# Epoch 59/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.1444e-04 - val_loss: 5.4085e-04
# Epoch 60/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.3215e-04 - val_loss: 4.6547e-04
# Epoch 61/150
# 916/916 [==============================] - 2s 2ms/step - loss: 4.0804e-04 - val_loss: 7.4278e-04
# Epoch 62/150
# 916/916 [==============================] - 2s 2ms/step - loss: 2.9974e-04 - val_loss: 4.7049e-04
# Epoch 63/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.4080e-04 - val_loss: 4.6246e-04
# Epoch 64/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.0495e-04 - val_loss: 5.3919e-04
# Epoch 65/150
# 916/916 [==============================] - 1s 2ms/step - loss: 3.3021e-04 - val_loss: 5.2444e-04
# Epoch 66/150
# 916/916 [==============================] - 2s 2ms/step - loss: 4.0818e-04 - val_loss: 6.8989e-04
# Epoch 67/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.4298e-04 - val_loss: 5.8178e-04
# Epoch 68/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.1547e-04 - val_loss: 4.7528e-04
# Epoch 69/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.2283e-04 - val_loss: 4.7804e-04
# Epoch 70/150
# 916/916 [==============================] - 2s 2ms/step - loss: 2.9811e-04 - val_loss: 5.6816e-04
# Epoch 71/150
# 916/916 [==============================] - 2s 2ms/step - loss: 2.9821e-04 - val_loss: 8.0509e-04
# Epoch 72/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.3944e-04 - val_loss: 5.5902e-04
# Epoch 73/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.1021e-04 - val_loss: 5.1172e-04
# Epoch 74/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.1730e-04 - val_loss: 5.6121e-04
# Epoch 75/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.0681e-04 - val_loss: 4.6937e-04
# Epoch 76/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.0387e-04 - val_loss: 4.6041e-04
# Epoch 77/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.3414e-04 - val_loss: 5.5381e-04
# Epoch 78/150
# 916/916 [==============================] - 2s 2ms/step - loss: 3.3582e-04 - val_loss: 5.4322e-04
# Epoch 00078: early stopping

# %% [markdown]
# ### 학습된 모델을 통해 예측한 주식 결과 출력
# `inverse_transform` 을 사용해 원래값으로 출력 가능

# %%
pred = model.predict(x_test)

plt.rcParams["figure.figsize"] = (10,5)
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['axes.grid'] = True 

plt.plot(y_test, color='b', label='True')
plt.plot(pred, color='r', label='Prediction')
plt.legend()

# %%
idx = date_idx[train_num:]
test_pred_inv = scaler.inverse_transform(pred)

plt.plot(idx, data['종가'][idx], label='True', color='b')
plt.plot(idx, test_pred_inv, label='Prediction_test', color='r')
plt.ylabel('Adj Close', fontsize=12)
plt.xlabel('Date', fontsize=12)
plt.legend()

# %% [markdown]
# ### 학습 과정 출력
# `loss` 와 `val_loss` 지표를 통해 과적합 유무 등을 판단할 수 있다.

# %%
plt.plot(training_result.history['loss'], 'y', label='train loss')
plt.plot(training_result.history['val_loss'], 'r', label='val loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='upper left')

plt.show()

# %%
loss_and_metrics = model.evaluate(x_test, y_test, batch_size=2)
print('loss : ' + str(loss_and_metrics))
# Out:
# 302/302 [==============================] - 0s 936us/step
# loss : 0.00016192974178707027

# %% [markdown]
# ### Model 저장하기 / 불러오기

# %%
model.save('stock_lstm_model.h5')

# %%
from keras.models import load_model
model_2 = load_model('stock_lstm_model.h5')

# %%
pred = model_2.predict(x_test)

plt.rcParams["figure.figsize"] = (10,5)
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['axes.grid'] = True 

plt.plot(y_test, color='b', label='True')
plt.plot(pred, color='r', label='Prediction')
plt.legend()
plt.show()
